# %% [markdown]
# <a href="https://colab.research.google.com/github/vedansha07/ai_ml_assignment/blob/main/ai_ml_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("joniarroba/noshowappointments")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'noshowappointments' dataset.
# Path to dataset files: /kaggle/input/noshowappointments

# %%
import numpy as np
